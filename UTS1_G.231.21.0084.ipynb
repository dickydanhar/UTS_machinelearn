# %%
import pandas as pd
import numpy as np

# %%
#  reading the data

data1 = pd.read_excel('/content/CADdataset.xlsx')

# checking the shapes of the data
print("Shape of Final Grades data :", data1.shape)
# Out:
# Shape of Final Grades data : (304, 100)

# %%
# looking at the final grades data

data1.head()
# Out:
#   Age Weight Height    Sex        BMI DM HTN Current Smoker Obesity DLP  ...  \
# 0  53     90    175   Male  29.387755  0   1              1       Y   Y  ...
# 1  67     70    157  Fmale  28.398718  0   1              0       Y   N  ...
# 2  54     54    164   Male  20.077335  0   0              1       N   N  ...
# 3  66     67    158  Fmale  26.838648  0   1              0       Y   N  ...
# 4  50     87    153  Fmale  37.165193  0   1              0       Y   N  ...
#
#   Unnamed: 90 Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94 Unnamed: 95  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 96 Unnamed: 97 Unnamed: 98 Unnamed: 99
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 100 columns]

# %%
data1.columns
# Out:
# Index(['Age', 'Weight', 'Height', 'Sex', 'BMI', 'DM', 'HTN', 'Current Smoker',
#        'Obesity', 'DLP', 'BP', 'WPE', 'Typical Chest Pain', 'Atypical',
#        'Nonanginal', 'St Depression', 'Tinversion', 'LVH', 'PRP', 'FBS', 'ESR',
#        'EF', ' RWMA', 'EX-Smoker', 'CR', 'BUN', 'CAD', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
#        'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
#        'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
#        'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
#        'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71',
#        'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75',
#        'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79',
#        'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83',
#        'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87',
#        'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91',
#        'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95',
#        'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99'],
#       dtype='object')

# %%
# describing the final grades data

data1.describe()
# Out:
#         Age  Weight  Height   Sex         BMI   DM  HTN  Current Smoker  \
# count   304     304     304   304  304.000000  304  304             304
# unique   47      55      45     3  263.000000    3    3               3
# top      55      75     170  Male   26.122449    0    1               0
# freq     18      22      23   176    4.000000  213  179             240
#
#        Obesity  DLP  ...   Unnamed: 90 Unnamed: 91  Unnamed: 92   Unnamed: 93  \
# count      304  304  ...             1           1            1             1
# unique       3    3  ...             1           1            1             1
# top          Y    N  ...  LCX Proximal     LCX Mid   LCX Distal  RCA Proximal
# freq       211  191  ...             1           1            1             1
#  76  Unnamed: 76         1 non-null      object
#  77  Unnamed: 77         1 non-null      object
#  78  Unnamed: 78         1 non-null      object
#  79  Unnamed: 79         1 non-null      object
#  80  Unnamed: 80         1 non-null      object
#  81  Unnamed: 81         1 non-null      object
#  82  Unnamed: 82         1 non-null      object
#  83  Unnamed: 83         1 non-null      object
#  84  Unnamed: 84         1 non-null      object
#  85  Unnamed: 85         1 non-null      object
#  86  Unnamed: 86         1 non-null      object
#  87  Unnamed: 87         1 non-null      object
#  88  Unnamed: 88         1 non-null      object
#  89  Unnamed: 89         1 non-null      object
#  90  Unnamed: 90         1 non-null      object
#  91  Unnamed: 91         1 non-null      object
#  92  Unnamed: 92         1 non-null      object
#  93  Unnamed: 93         1 non-null      object
#  94  Unnamed: 94         1 non-null      object
#  95  Unnamed: 95         1 non-null      object
#  96  Unnamed: 96         1 non-null      object
#  97  Unnamed: 97         1 non-null      object
#  98  Unnamed: 98         1 non-null      object
#  99  Unnamed: 99         1 non-null      object
# dtypes: object(100)
# memory usage: 237.6+ KB

# %%
# checking if there exists any NULL values in the dataset

data1.isnull().sum()
# Out:
# Age              0
# Weight           0
# Height           0
# Sex              0
# BMI              0
#               ...
# Unnamed: 95    303
# Unnamed: 96    303
# Unnamed: 97    303
# Unnamed: 98    303
# Unnamed: 99    303
# Length: 100, dtype: int64

# %%
# checking the data types of the data

data1.dtypes
# Out:
# Age            object
# Weight         object
# Height         object
# Sex            object
# BMI            object
#                 ...
# Unnamed: 95    object
# Unnamed: 96    object
# Unnamed: 97    object
# Unnamed: 98    object
# Unnamed: 99    object
# Length: 100, dtype: object

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y  = make_blobs?

# %%
X,y  = make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k = 5

color  = ["green","red","blue","yellow","orange"]

clusters = {}

for i in range(k):
    center = 10*(2*np.random.random((X.shape[1],))-1)
    points = []

    cluster = {
        'center':center,
        'points':points,
        'color': color[i]
        }

    clusters[i] = cluster

# %%
#center = 10*(2*np.random.random((X.shape[1],))-1)
#print(center)

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# Assign every data point to one of the clusters
def assignPointToClusters(clusters): #E-Step
    for ix in range(X.shape[0]):
        dist = []
        curr_x = X[ix]

        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)

        current_cluster = np.argmin(dist)
        clusters[current_cluster]['points'].append(curr_x)

def updateClusters(clusters): # M-Step -> We update every cluster center according to the mean of the points in it
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])

        if pts.shape[0]>0: #If a cluster has some-nonzero points
            new_u = pts.mean(axis=0)
            clusters[kx]['center'] = new_u
            clusters[kx]['points'] = [] #Clear the list



def plotClusters(clusters):

    for kx in range(k):
        #print(len(clusters[kx]['points']))

        pts = np.array(clusters[kx]['points'])
        #print(pts.shape)

        #Plot the points
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass

        #Plot the cluster center
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
plotClusters(clusters)

# %%
# Repeat this cell few times or put it inside a loop
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
